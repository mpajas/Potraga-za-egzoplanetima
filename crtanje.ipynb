# %%
# %config IPCompleter.greedy=True
#%matplotlib inline

# %%
import numpy as np
import random
import pandas as pd

#crtanje
import matplotlib.pyplot as plt
import seaborn as sns
#sns.set_theme()
sns.set(style="white")

# %%
#kvadratna funkcija
fig, ax = plt.subplots(figsize=(8,6))
xs = np.arange(-2,2,0.1)
ys = xs**2
ax.plot(xs,ys, lw=4)
#cost function logističke funkcije
xs = np.arange(0.01,1,0.01)
ys = -(np.log(xs) + np.log(1-xs))
#plt.plot(xs,ys)

ax.spines['top'].set_color('none')
ax.spines['bottom'].set_position('zero')
ax.spines['left'].set_position('zero')
ax.spines['right'].set_color('none')
ax.set_xlim(-1.5,1.5)
ax.set_ylim(0,2)
fig.savefig("Slike\kvadratna_funkcija.png")

# %%
#cost function logističke funkcije
fig, ax = plt.subplots(figsize=(8,6))
xs = np.arange(0.01,1,0.01)
# ys = -(np.log(xs) + np.log(1-xs))
# ax.plot(xs,ys, lw=4)
ax.set_xlim(-1,1)
ax.set_ylim(0,4)
ax.spines['top'].set_color("none")
ax.spines['bottom'].set_position(("axes", 0.01))
ax.spines['left'].set_position("zero")
ax.spines['right'].set_color("none")

ys1 = -(np.log(xs))
ys2 = -np.log(1-xs)
ys = -(np.log(xs) + np.log(1-xs))
ax.plot(xs,ys, lw=2, ls="--", c="black", zorder=1)
ax.plot(xs,ys1, lw=4, zorder=-1, label=r"$-\log(\hat{p})$, $\hat{y} = 1$")
ax.plot(xs,ys2, lw=4, zorder=-1, label=r"$-\log(1-\hat{p})$, $\hat{y} = 0$")


fig.savefig("Slike\logistic_cost_function.png")

# %%
#kvadratna funkcija
fig, ax = plt.subplots(figsize=(10,8))

#just enough
x = np.arange(-1,0.1,0.1)
#premali korak
#x = np.arange(-1,-0.45,0.05)
#preveliki korak
#x = np.arange(-1,1,0.5)
y = x**2

xs = np.arange(-2,2,0.1)
ys = xs**2



ax.scatter(x,y,s=200,color="red", zorder=1, alpha=0.7)
ax.plot(xs,ys,lw=4, zorder=-1)

#cost function logističke funkcije
# xs = np.arange(0.01,1,0.01)
# ys = -(np.log(xs) + np.log(1-xs))
#plt.plot(xs,ys)

# ax.spines['top'].set_color('none')
# ax.spines['bottom'].set_position('zero')
# ax.spines['left'].set_position('zero')
# ax.spines['right'].set_color('none')
ax.set_xlim(-1.5,1.5)
ax.set_ylim(-0.5,2.5)
ax.set_xlabel("$w$", fontsize=22)
ax.set_ylabel("trošak", fontsize=22)
ax.set_xticks(())
ax.set_yticks(())
#fig.legend()
fig.savefig("Slike\gradient_descent.png")

# %%
#fitanje kvadratne funkcije različitim modelima
plt.figure(figsize=(10,8))
random.seed(4)
noise = 16
xs = np.arange(-5,10,0.5)
ys = [x**2 + noise*random.random()-noise for x in xs]

plt.scatter(xs,ys)
plt.xticks(())
plt.yticks(())
# Out:
# ([], [])

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline


xs2 = np.arange(-7,12,0.5)

model = Pipeline([('poly', PolynomialFeatures(degree=1)),
                  ('linear', LinearRegression(fit_intercept=False))])

model.fit(xs[:,np.newaxis],ys)

ys2 = model.predict(xs2[:,np.newaxis])
fig, ax = plt.subplots(figsize=(8,5))

ax.scatter(xs,ys)
ax.plot(xs2,ys2, ls="--", c="red")
ax.set_xticks(())
ax.set_yticks(())
#ax.set_xlim((-5,5))
fig.savefig("Slike\poor_fit.png")

# %%
xs2 = np.arange(-7,12,0.5)

model = Pipeline([('poly', PolynomialFeatures(degree=2)),
                  ('linear', LinearRegression(fit_intercept=False))])

model.fit(xs[:,np.newaxis],ys)

ys2 = model.predict(xs2[:,np.newaxis])

fig, ax = plt.subplots(figsize=(8,5))

ax.scatter(xs,ys)
ax.plot(xs2,ys2, ls="--", c="red")
ax.set_xticks(())
ax.set_yticks(())
fig.savefig("Slike\good_fit.png")

# %%
xs2 = np.arange(-7,12,0.5)

model = Pipeline([('poly', PolynomialFeatures(degree=16)),
                  ('linear', LinearRegression(fit_intercept=False))])
plt.figure(figsize=(8,5))
model.fit(xs[:,np.newaxis],ys)

ys2 = model.predict(xs2[:,np.newaxis])
fig, ax = plt.subplots(figsize=(8,5))

ax.scatter(xs,ys)
ax.plot(xs2,ys2, ls="--", c="red")
ax.set_xticks(())
ax.set_yticks(())
ax.set_ylim(-20,120)
fig.savefig("Slike\over_fit.png")

# %%
#logistička funkcija
plt.rc('xtick', labelsize=16) 
plt.rc('ytick', labelsize=16) 
fig, ax = plt.subplots(figsize=(12,6))
xs = np.arange(-10,10,0.01)
ys = 1/(1+np.exp(-xs))
ax.plot(xs,ys, lw=3, label=r"$\sigma(t) = \dfrac{1}{1+e^{-t}}$")
#plt.plot(xs,ys)

ax.spines['top'].set_color('none')
ax.spines['bottom'].set_position('zero')
ax.spines['left'].set_position('zero')
ax.spines['right'].set_color('none')
ax.set_xlim(-10,10)
ax.set_ylim(0,1.1)
ax.set_xlabel(r"$t$", fontsize=22)
ax.set_yticks(np.arange(0,1.2,0.5))
ax.legend(fontsize=22)
fig.savefig("Slike\logisticka_funkcija.png")

# %%
#cost function logističke funkcije
fig, ax = plt.subplots(figsize=(12,8))
xs = np.arange(0.01,1,0.01)
ys1 = -(np.log(xs))
ys2 = -np.log(1-xs)
ys = -(np.log(xs) + np.log(1-xs))
ax.plot(xs,ys, lw=2, ls="--", c="black", zorder=1)
ax.plot(xs,ys1, lw=4, zorder=-1, label=r"$-\log(\hat{p})$, $y = 1$")
ax.plot(xs,ys2, lw=4, zorder=-1, label=r"$-\log(1-\hat{p})$, $y = 0$")
ax.set_xlim(-1,1)
ax.set_ylim(0,4)
ax.set_xlabel(r"$\hat{p}$", fontsize=18)
ax.set_xticks([0,0.25,0.5,0.75,1])
ax.spines['top'].set_color("none")
ax.spines['bottom'].set_position(("axes", 0.01))
ax.spines['left'].set_position("zero")
ax.spines['right'].set_color("none")
ax.legend(fontsize=22)
fig.savefig("Slike\log_cost_fun.png")

# %%
fig = plt.figure(figsize=(10, 4))
ax = fig.add_axes([0, 0, 0.7, 1], frameon=False, xticks=[], yticks=[])
#ax.set_title('Example Decision Tree: Animal Classification', size=24)

def text(ax, x, y, t, size=20, **kwargs):
    ax.text(x, y, t,
            ha='center', va='center', size=size,
            bbox=dict(boxstyle='round', ec='k', fc='w'), **kwargs)

text(ax, 0.5, 0.9, "Kakvo je vrijeme?", 20)
text(ax, 0.3, 0.6, "Je li temperatura \nviša od 18 °C?", 18)
text(ax, 0.7, 0.6, "Puše li jak \nvjetar?", 18)
text(ax, 0.12, 0.3, "Nosi jaknu.", 14)
text(ax, 0.38, 0.3, "Ne nosi \njaknu.", 14)
text(ax, 0.62, 0.3, "Ne nosi \njaknu.", 14)
text(ax, 0.88, 0.3, "Nosi jaknu", 14)

text(ax, 0.4, 0.75, "Sunčano", 12, alpha=0.6)
text(ax, 0.6, 0.75, "Kišno", 12, alpha=0.6)

text(ax, 0.21, 0.45, "T < 18 °C", 12, alpha=0.6)
text(ax, 0.34, 0.45, "T > 18 °C", 12, alpha=0.6)

text(ax, 0.66, 0.45, "Ne", 12, alpha=0.6)
text(ax, 0.79, 0.45, "Da", 12, alpha=0.6)

ax.plot([0.3, 0.5, 0.7], [0.6, 0.9, 0.6], '-k')
ax.plot([0.12, 0.3, 0.38], [0.3, 0.6, 0.3], '-k')
ax.plot([0.62, 0.7, 0.88], [0.3, 0.6, 0.3], '-k')
ax.axis([0, 1, 0.2, 1])

#fig.savefig("Slike/stablo_odlucivanja_jakna.png")
# Out:
# (0.0, 1.0, 0.2, 1.0)

# %%
def visualize_classifier(model, X, y, ax=None, cmap='rainbow'):
    ax = ax or plt.gca()
    
    # Plot the training points
    ax.scatter(X[:, 0], X[:, 1], c=y, s=30, cmap=cmap,
               clim=(y.min(), y.max()), zorder=3)
    ax.axis('tight')
    ax.axis('off')
    xlim = ax.get_xlim()
    ylim = ax.get_ylim()
    
    # fit the estimator
    model.fit(X, y)
    xx, yy = np.meshgrid(np.linspace(*xlim, num=200),
                         np.linspace(*ylim, num=200))
    Z = model.predict(np.c_[xx.ravel(), yy.ravel()]).reshape(xx.shape)

    # Create a color plot with the results
    n_classes = len(np.unique(y))
    contours = ax.contourf(xx, yy, Z, alpha=0.3,
                           levels=np.arange(n_classes + 1) - 0.5,
                           cmap=cmap, clim=(y.min(), y.max()),
                           zorder=1)

    ax.set(xlim=xlim, ylim=ylim)

# %%
from sklearn.datasets import make_blobs
from sklearn.tree import DecisionTreeClassifier

X, y = make_blobs(n_samples=300, centers=4,
                  random_state=4, cluster_std=2.0)

fig, ax = plt.subplots(figsize=(6,6))
ax.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='rainbow');
ax.set_xticks(())
ax.set_yticks(())
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# %%
fig, ax = plt.subplots(figsize=(6,6))
visualize_classifier(DecisionTreeClassifier(max_depth=1), X, y)
ax.set_xticks(())
ax.set_yticks(())
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
fig.savefig("Slike/tree_blobs_1.png")
# Out:
# <ipython-input-13-2012e9cc4787>:20: UserWarning: The following kwargs were not used by contour: 'clim'
#   contours = ax.contourf(xx, yy, Z, alpha=0.3,

# %%
fig, ax = plt.subplots(figsize=(6,6))
visualize_classifier(DecisionTreeClassifier(max_depth=2), X, y)
ax.set_xticks(())
ax.set_yticks(())
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
fig.savefig("Slike/tree_blobs_2.png")
# Out:
# <ipython-input-13-2012e9cc4787>:20: UserWarning: The following kwargs were not used by contour: 'clim'
#   contours = ax.contourf(xx, yy, Z, alpha=0.3,

# %%
fig, ax = plt.subplots(figsize=(6,6))
visualize_classifier(DecisionTreeClassifier(max_depth=10), X, y)
ax.set_xticks(())
ax.set_yticks(())
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
fig.savefig("Slike/tree_blobs_10.png")
# Out:
# <ipython-input-13-2012e9cc4787>:20: UserWarning: The following kwargs were not used by contour: 'clim'
#   contours = ax.contourf(xx, yy, Z, alpha=0.3,

# %%
from sklearn.tree import export_graphviz

tree = DecisionTreeClassifier(max_depth=2, criterion="entropy")
tree.fit(X,y)

export_graphviz(
tree,
out_file="treeentropy2.dot",
feature_names=[r"x_1", "x_2"],
class_names=["y_1", "y_2", "y_3", "y_4"],
rounded=True,
filled=True
)

# %%
# Učitaj nanovo podatke bez ikakvih transformacija
def reset_data(df_train, df_test):
    train = df_train.copy()
    test = df_test.copy()
    
    #pretvori LABEL u tvrdnje istinitosti 0 i 1
    train["LABEL"] = train["LABEL"].apply(lambda x: 0 if x==1 else 1)
    test["LABEL"] = test["LABEL"].apply(lambda x: 0 if x==1 else 1)
    
    #razdvoji feature i labele
    X_train = train.drop(["LABEL"], axis = 1)
    y_train = train["LABEL"].ravel()
    X_test = test.drop(["LABEL"], axis = 1)
    y_test = test["LABEL"].ravel()
    
    #makni retke koji sadrže outliere u train data
    zscores = zscore(X_train)
    abszscores = np.abs(zscores)
    filtered_indices = (abszscores<3).all(axis=1)
    X_train = X_train[filtered_indices]
    y_train = y_train[filtered_indices]
    
    #ispuni outliere retka sa srednjom vrijednosti retka
#     data_std = X_train.std(axis=1)
#     data_mean = X_train.mean(axis=1)
#     cut = data_std*3

#     outliers = []
#     for i in range(len(X_train)):
#         outliers.append(X_train.iloc[i]>cut[i])
    
#     X_train[np.array(outliers)] = np.nan
    
#     for i in range(len(X_train)):
#         X_train.iloc[i].fillna(data_mean[i], inplace=True)
    
    return X_train, X_test, y_train, y_test

# %%
print("Loading data...")
train_data = pd.read_csv("exoTrain.csv")#.fillna(0)
test_data = pd.read_csv("exoTest.csv")#.fillna(0)
print("Data loaded.")
# Out:
# Loading data...
# Data loaded.

# %%
plt.rc('xtick', labelsize=26) 
plt.rc('ytick', labelsize=26) 
fig, ax = plt.subplots(nrows=4, ncols=2, figsize=(28,14), sharex="all")

plt.setp(ax, xticks=list(range(0,3201,400)), xticklabels=list(range(0,90,10)))
x = [29,  67, 141, 159, 287, 342, 372, 394]
k = 0
for i in range(4):
    for j in range(2):
        ax[i,j].plot(np.arange(len(test_data.iloc[0])),test_data.iloc[x[k],:], )#s=0.2)
        #ax[i,j].set_xticks(list(range(0,3197,40)),list(range(1,81)))
        k+=1

fig.text(0.5, 0.07, "Vrijeme [dani]", ha='center', fontsize=32)
fig.text(0.06, 0.5, "Nenormalizirani intenzitet svjetlosti [$e^{-}s^{-1}$]", va='center', rotation='vertical', fontsize=32)
#fig.savefig("Slike/ansambl_false_positives_raw.png")

# %%
labels = train_data.LABEL
train_data = train_data.drop('LABEL',axis=1)
#train_data[labels==2].median(axis=1).describe()

# %%
n = 80
N = 3197
N/n
a = list(range(0,3201,400))
3197/((N/n)*10)
(N/n)*10
a
list(range(0,90,10))
# Out:
# [0, 10, 20, 30, 40, 50, 60, 70, 80]

# %%
plt.rc('xtick', labelsize=26) 
plt.rc('ytick', labelsize=26) 
fig, ax = plt.subplots(nrows=6, ncols=2, figsize=(28,14), sharex="all")
plt.setp(ax, xticks=list(range(0,3201,400)), xticklabels=list(range(0,90,10)))

x = train_data[labels==2]
k = 0
for i in range(6):
    for j in range(2):
        ax[i,j].plot(np.arange(len(x.iloc[0])),x.iloc[k,:], )#s=0.2)
        #ax[i,j].set_xticks(list(range(0,3197,40)),list(range(1,81)))
        k+=1

fig.text(0.5, 0.07, "Vrijeme [dani]", ha='center', fontsize=32)
fig.text(0.07, 0.5, "Nenormalizirani intenzitet svjetlosti [$e^{-}s^{-1}$]", va='center', rotation='vertical', fontsize=32)
#fig.savefig("Slike/flux_s_exo_raw.png")

# %%
plt.rc('xtick', labelsize=26) 
plt.rc('ytick', labelsize=26) 
fig, ax = plt.subplots(nrows=6, ncols=2, figsize=(28,14), sharex="all")
plt.setp(ax, xticks=list(range(0,3201,400)), xticklabels=list(range(0,90,10)))

x = train_data[labels==1]
k = 0
for i in range(6):
    for j in range(2):
        ax[i,j].plot(np.arange(len(x.iloc[0])),x.iloc[k,:], )#s=0.2)
        k+=1

fig.text(0.5, 0.07, "Vrijeme [dani]", ha='center', fontsize=32)
fig.text(0.07, 0.5, "Nenormalizirani intenzitet svjetlosti [$e^{-}s^{-1}$]", va='center', rotation='vertical', fontsize=32)
#fig.savefig("Slike/flux_bez_exo_raw.png")

# %%
x = train_data[labels==2]
i = 35
#len(x.iloc[4])
n = 500
plt.rc('xtick', labelsize=16) 
plt.rc('ytick', labelsize=16) 
fig, ax = plt.subplots(figsize=(14,6))
plt.setp(ax, xticks=list(range(0,500,40)), xticklabels=list(range(0,13)))
plt.xlabel("Vrijeme [dani]", fontsize=22)
plt.ylabel("Nenormalizirani intenzitet svjetlosti [$e^{-}s^{-1}$]", fontsize=22)
ax.scatter(np.arange(n),x.iloc[i,:n], s=10)
#plt.scatter(np.arange(n),x.iloc[11,:n], s=10)
#fig.savefig("Slike/zoomed_in.png")

# %%
from sklearn.base import BaseEstimator, TransformerMixin
from scipy.signal import savgol_filter
from scipy.stats import zscore
from scipy.fft import rfft, rfftfreq
from scipy import ndimage #za gaussijanski filter
from sklearn.preprocessing import StandardScaler, RobustScaler, normalize

class FastFourierTransform(BaseEstimator, TransformerMixin):
    def __init__(self): # no *args or **kargs
        pass
    def fit(self, X, y=None):
        return self # nothing else to do
    def transform(self, X, y=None):
        transformed = np.abs(rfft(X, axis=1))
        return transformed
    
class SavGolTransform(BaseEstimator, TransformerMixin):
    def __init__(self): # no *args or **kargs
        pass
    def fit(self, X, y=None):
        return self # nothing else to do
    def transform(self, X, y=None):
        transformed = savgol_filter(X,21,2,deriv=0)
        return transformed
    
class NormalizeTransform(BaseEstimator, TransformerMixin):
    def __init__(self): # no *args or **kargs
        pass
    def fit(self, X, y=None):
        return self # nothing else to do
    def transform(self, X, y=None):
        transformed = normalize(X)
        return transformed

class GaussianFilter(BaseEstimator, TransformerMixin):
    def __init__(self): # no *args or **kargs
        pass
    def fit(self, X, y=None):
        return self # nothing else to do
    def transform(self, X, y=None):
        #transformed = []
#         for x in X:
#             transformed.append(ndimage.filters.gaussian_filter(x, sigma=10))
        transformed = ndimage.filters.gaussian_filter(X, sigma=0.5)
        return transformed

# %%
print("Loading data...")
train_data = pd.read_csv("exoTrain.csv")#.fillna(0)
test_data = pd.read_csv("exoTest.csv")#.fillna(0)
print("Data loaded.")
labels = train_data.LABEL
train_data = train_data.drop('LABEL',axis=1)
#train_data[labels==2].median(axis=1).describe()

#savgol prije --> fft izgleda ružno
savgol = SavGolTransform()
train_data = pd.DataFrame(np.array(train_data) - savgol.transform(train_data))

fourier = FastFourierTransform()
train_data = pd.DataFrame(fourier.transform(train_data))

train_data = pd.DataFrame(normalize(train_data))

# std = StandardScaler()
# std.fit(train_data)
# train_data = pd.DataFrame(std.transform(train_data))


# savgol = SavGolTransform()
# train_data = pd.DataFrame(savgol.transform(train_data))
# Out:
# Loading data...
# Data loaded.

# %%
import scipy
# scale = scipy.fft.rfftfreq(3197, d=0.025)
# scale_labels = scale[::300].round()
# scale_ticks = list(range(1599))[::300]
scale = scipy.fft.rfftfreq(3197, d=80/3197)
scale_labels = scale[::300].round(3)
scale_ticks = list(range(1599))[::300]

plt.rc('xtick', labelsize=26) 
plt.rc('ytick', labelsize=26) 
fig, ax = plt.subplots(nrows=6, ncols=2, figsize=(28,14), sharex="all")

plt.setp(ax, xticks=scale_ticks, xticklabels=scale_labels)

x = train_data[labels==2]
k = 0
for i in range(6):
    for j in range(2):
        ax[i,j].plot(np.arange(len(x.iloc[0])),x.iloc[k,:], )#s=0.2)
        #ax[i,j].set_xticks(list(range(0,3197,40)),list(range(1,81)))
        k+=1

fig.text(0.5, 0.06, r"Frekvencija [$\mathrm{dan}^{-1}$]", ha='center', fontsize=32)
fig.text(0.07, 0.5, "Normalizirana amplituda intenziteta svjetlosti [$e^{-}s^{-1}$]", va='center', rotation='vertical', fontsize=32)
#fig.savefig("Slike/flux_s_exo_obrađen.png")
# Out:
# Text(0.07, 0.5, 'Normalizirana amplituda intenziteta svjetlosti [$e^{-}s^{-1}$]')

# %%
import scipy
# scale = scipy.fft.rfftfreq(3197, d=0.025)
# scale_labels = scale[::300].round()
# scale_ticks = list(range(1599))[::300]
scale = scipy.fft.rfftfreq(3197, d=80/3197)
scale_labels = scale[::300].round(3)
scale_ticks = list(range(1599))[::300]

plt.rc('xtick', labelsize=26) 
plt.rc('ytick', labelsize=26) 
fig, ax = plt.subplots(nrows=6, ncols=2, figsize=(28,14), sharex="all")

plt.setp(ax, xticks=scale_ticks, xticklabels=scale_labels)

x = train_data[labels==2]
k = 0
for i in range(6):
    for j in range(2):
        ax[i,j].plot(np.arange(len(x.iloc[0])),x.iloc[k,:], )#s=0.2)
        #ax[i,j].set_xticks(list(range(0,3197,40)),list(range(1,81)))
        k+=1

fig.text(0.5, 0.06, r"Frekvencija [$\mathrm{dan}^{-1}$]", ha='center', fontsize=32)
fig.text(0.07, 0.5, "Normalizirana amplituda intenziteta svjetlosti [$e^{-}s^{-1}$]", va='center', rotation='vertical', fontsize=32)
#fig.savefig("Slike/flux_s_exo_obrađen.png")
# Out:
# Text(0.07, 0.5, 'Normalizirana amplituda intenziteta svjetlosti [$e^{-}s^{-1}$]')

# %%
import scipy
# scale = scipy.fft.rfftfreq(3197, d=0.025)
# scale_labels = scale[::300].round()
# scale_ticks = list(range(1599))[::300]
scale = scipy.fft.rfftfreq(3197, d=80/3197)
scale_labels = scale[::300].round(3)
scale_ticks = list(range(1599))[::300]

plt.rc('xtick', labelsize=26) 
plt.rc('ytick', labelsize=26) 
fig, ax = plt.subplots(nrows=6, ncols=2, figsize=(28,14), sharex="all")

plt.setp(ax, xticks=scale_ticks, xticklabels=scale_labels)

x = train_data[labels==1]
k = 0
for i in range(6):
    for j in range(2):
        ax[i,j].plot(np.arange(len(x.iloc[0])),x.iloc[k,:], )#s=0.2)
        #ax[i,j].set_xticks(list(range(0,3197,40)),list(range(1,81)))
        k+=1

fig.text(0.5, 0.06, r"Frekvencija [$\mathrm{dan}^{-1}$]", ha='center', fontsize=32)
fig.text(0.07, 0.5, "Normalizirana amplituda intenziteta svjetlosti [$e^{-}s^{-1}$]", va='center', rotation='vertical', fontsize=32)

fig.savefig("Slike/flux_bez_exo_obrađen.png")

# %%
print("Loading data...")
train_data = pd.read_csv("exoTrain.csv")#.fillna(0)
test_data = pd.read_csv("exoTest.csv")#.fillna(0)
print("Data loaded.")
labels = train_data.LABEL
train_data = train_data.drop('LABEL',axis=1)
#train_data[labels==2].median(axis=1).describe()
# Out:
# Loading data...
# Data loaded.

# %%
import scipy
# scale = scipy.fft.rfftfreq(3197, d=0.025)
# scale_labels = scale[::300].round()
# scale_ticks = list(range(1599))[::300]
scale = scipy.fft.rfftfreq(3197, d=80/3197)
scale_labels = scale[::300].round(3)
scale_ticks = list(range(1599))[::300]

plt.rc('xtick', labelsize=26) 
plt.rc('ytick', labelsize=26) 
fig, ax = plt.subplots(nrows=4, ncols=3, figsize=(28,14), sharex="all")

plt.setp(ax, xticks=scale_ticks, xticklabels=scale_labels)

x = train_data[labels==1]
k = 0
for i in range(4):
    for j in range(3):
        ax[i,j].plot(np.arange(len(x.iloc[0])),x.iloc[k,:], )#s=0.2)
        #ax[i,j].set_xticks(list(range(0,3197,40)),list(range(1,81)))
        k+=1

fig.text(0.5, 0.06, r"Frekvencija [$\mathrm{dan}^{-1}$]", ha='center', fontsize=32)
fig.text(0.07, 0.5, "Normalizirana amplituda intenziteta svjetlosti [$e^{-}s^{-1}$]", va='center', rotation='vertical', fontsize=32)

#fig.savefig("Slike/flux_bez_exo_obrađen.png")

# %%
# from sklearn import LogisticRegression
# from sklearn.metrics import confusion_matrix,

# logreg = LogisticRegression(C=8,max_iter=1000, n_jobs=-1)
# logreg.fit(X_train, y_train)
# y_pred = logreg.predict(X_test)
# confusion_matrix(y_test,y_pred)

# %%
# fig = plt.figure(figsize=(24,40))

# x = train_data[labels==2]
# for i in range(12):
#     ax = fig.add_subplot(14,3,i+1)
    
#     #ax.scatter(np.arange(len(data[0])),data[i][:],s=0.5)
#     n = 500
#     #N = len(x.iloc[0,:n])
#     #ax.scatter(np.arange(len(x.iloc[0])),x.iloc[i,:], s=0.5)
#     ax.plot(np.arange(len(x.iloc[0])),x.iloc[i,:])#, s=0.2)
#     #ax.title.set_text(f"Zvijezda {i}")
#     #ax.plot(np.arange(n),x.iloc[i,1000:1000+n], lw=0.5)
# #fig.savefig("Slike/flux_s_exo_raw.png")

# %%
# fig = plt.figure(figsize=(24,40))
# x = train_data[labels==1]
# for i in range(12):
#     ax = fig.add_subplot(14,3,i+1)
#     #ax.scatter(np.arange(len(data[0])),data[i][:],s=0.5)
#     n=500
#     #ax.scatter(np.arange(len(x.iloc[0])),x.iloc[i,:], s=0.2)
#     ax.plot(np.arange(len(x.iloc[0])),x.iloc[i,:])#, s=0.2)
#     #ax.plot(np.arange(n),x.iloc[i,1000:1000+n], lw=0.5)
# #fig.savefig("Slike/flux_bez_exo_raw.png")

# %%
print("Loading data...")
train_data = pd.read_csv("exoTrain.csv")#.fillna(0)
test_data = pd.read_csv("exoTest.csv")#.fillna(0)
print("Data loaded.")
labels = train_data.LABEL
train_data = train_data.drop('LABEL',axis=1)
#train_data[labels==2].median(axis=1).describe()

#savgol prije --> fft izgleda ružno
# savgol = SavGolTransform()
# train_data = pd.DataFrame(np.array(train_data) - savgol.transform(train_data))

# fourier = FastFourierTransform()
# train_data = pd.DataFrame(fourier.transform(train_data))

# train_data = pd.DataFrame(normalize(train_data))

# std = StandardScaler()
# std.fit(train_data)
# train_data = pd.DataFrame(std.transform(train_data))


# savgol = SavGolTransform()
# train_data = pd.DataFrame(savgol.transform(train_data))
# Out:
# Loading data...
# Data loaded.

# %%
plt.rc('xtick', labelsize=20) 
plt.rc('ytick', labelsize=20) 

x = train_data[labels==2]
i = 18
#i = 35
#fig = plt.figure(figsize=(10,10))

fig, ax = plt.subplots(figsize=(12,8))
ax.plot(np.arange(len(x.iloc[0])),x.iloc[i,:])
plt.setp(ax, xticks=list(range(0,3201,400)), xticklabels=list(range(0,90,10)))
n = 500
#ax.plot(np.arange(n),x.iloc[i,:n])

plt.xlabel("Vrijeme [dani]", fontsize=26)
plt.ylabel("Nenormalizirani intenzitet svjetlosti [$e^{-}s^{-1}$]", fontsize=26)
fig.savefig("Slike/obrada_1")

# %%
train_data = pd.DataFrame(normalize(train_data))


# gauss = GaussianFilter()
# gauss_data = gauss.transform(train_data)
# gauss_data = pd.DataFrame(gauss_data)

savgol = SavGolTransform()
savgol_data = savgol.transform(train_data)
savgol_data = pd.DataFrame(savgol_data)

x = train_data[labels==2]

#fig = plt.figure(figsize=(24,40))
fig, ax = plt.subplots(figsize=(12,8))
#ax.plot(np.arange(len(x.iloc[0])), x.iloc[35,:])
n = 500
ax.plot(np.arange(len(x.iloc[35,:])), x.iloc[i,:])
ax.plot(np.arange(len(x.iloc[35,:])), savgol_data.iloc[i,:], color="red", alpha=0.8)

plt.setp(ax, xticks=list(range(0,3201,400)), xticklabels=list(range(0,90,10)))
plt.xlabel("Vrijeme [dani]", fontsize=26)
plt.ylabel("Normalizirani intenzitet svjetlosti [$e^{-}s^{-1}$]", fontsize=26)
#ax.scatter(np.arange(n), x.iloc[i,:n])
# ax.plot(np.arange(n), savgol_data.iloc[i,:n], color="red", alpha=0.8)
fig.savefig("Slike/obrada_2")

# %%
train_data = pd.DataFrame(np.array(train_data) - np.array(savgol_data))
#train_data = pd.DataFrame(np.array(train_data) - np.array(gauss_data))
x = train_data[labels==2]

#fig = plt.figure(figsize=(24,40))
fig, ax = plt.subplots(figsize=(12,8))
#ax.plot(np.arange(len(x.iloc[0])), x.iloc[35,:])
n = 500
ax.plot(np.arange(len(x.iloc[35,:])), x.iloc[i,:])
plt.setp(ax, xticks=list(range(0,3201,400)), xticklabels=list(range(0,90,10)))
plt.xlabel("Vrijeme [dani]", fontsize=26)
plt.ylabel("Normalizirani intenzitet svjetlosti [$e^{-}s^{-1}$]", fontsize=26)

#ax.plot(np.arange(len(x.iloc[35,:])), savgol_data.iloc[35,:])
fig.savefig("Slike/obrada_3")

# %%
fourier = FastFourierTransform()
train_data = pd.DataFrame(fourier.transform(train_data))

x = train_data[labels==2]

#fig = plt.figure(figsize=(24,40))
fig, ax = plt.subplots(figsize=(12,8))
#ax.plot(np.arange(len(x.iloc[0])), x.iloc[35,:])
n = 500
ax.plot(np.arange(len(x.iloc[35,:])), x.iloc[i,:])
plt.xlabel(r"Frekvencija [$\mathrm{dan}^{-1}$]", fontsize=26)
plt.ylabel("Normalizirana amplituda intenziteta svjetlosti [$e^{-}s^{-1}$]", fontsize=24)
scale = scipy.fft.rfftfreq(3197, d=80/3197)
scale_labels = scale[::300].round(3)
scale_ticks = list(range(1599))[::300]
plt.setp(ax, xticks=scale_ticks, xticklabels=scale_labels)
fig.savefig("Slike/obrada_4")

# %%
# train_data = pd.DataFrame(normalize(train_data))

# x = train_data[labels==2]

# #fig = plt.figure(figsize=(24,40))
# fig, ax = plt.subplots(figsize=(12,6))
# #ax.plot(np.arange(len(x.iloc[0])), x.iloc[35,:])
# n = 500
# ax.plot(np.arange(len(x.iloc[35,:])), x.iloc[i,:])

# %%
std = StandardScaler()
std.fit(train_data)
train_data = pd.DataFrame(std.transform(train_data))

x = train_data[labels==2]

#fig = plt.figure(figsize=(24,40))
fig, ax = plt.subplots(figsize=(12,8))
#ax.plot(np.arange(len(x.iloc[0])), x.iloc[35,:])
n = 500
ax.plot(np.arange(len(x.iloc[35,:])), x.iloc[i,:])
plt.xlabel(r"Frekvencija [$\mathrm{dan}^{-1}$]", fontsize=26)
plt.ylabel("Normalizirana amplituda intenziteta svjetlosti [$e^{-}s^{-1}$]", fontsize=24)
scale = scipy.fft.rfftfreq(3197, d=80/3197)
scale_labels = scale[::300].round(3)
scale_ticks = list(range(1599))[::300]
plt.setp(ax, xticks=scale_ticks, xticklabels=scale_labels)
fig.savefig("Slike/obrada_5")

# %%
def stats_plots_label(df,labels):
#     means1 = df[labels==1].mean(axis=1)
#     medians1 = df[labels==1].median(axis=1)
#     std1 = df[labels==1].std(axis=1)
#     maxval1 = df[labels==1].max(axis=1)
#     minval1 = df[labels==1].min(axis=1)
#     skew1 = df[labels==1].skew(axis=1)
    means1 = df.mean(axis=1)
    medians1 = df.median(axis=1)
    std1 = df.std(axis=1)
    maxval1 = df.max(axis=1)
    minval1 = df.min(axis=1)
    skew1 = df.skew(axis=1)
    
    means2 = df[labels==2].mean(axis=1)
    medians2 = df[labels==2].median(axis=1)
    std2 = df[labels==2].std(axis=1)
    maxval2 = df[labels==2].max(axis=1)
    minval2 = df[labels==2].min(axis=1)
    skew2 = df[labels==2].skew(axis=1)
    fig = plt.figure(figsize=(18,12))
    ax = fig.add_subplot(231)
    ax.hist(means1,alpha=0.8,bins=50,color='b',range=(-250,250))
    #ax.hist(means2,alpha=0.8,bins=50,color='r',density=True,range=(-250,250))
    ax.get_legend()
    ax.set_xlabel("Srednja vrijednost intenziteta svjetlosti", fontsize=20)
    ax.set_ylabel("Broj zvijezdi", fontsize=20)
    ax = fig.add_subplot(232)
    ax.hist(medians1,alpha=0.8,bins=50,color='b',range=(-0.1,0.1))
    #ax.hist(medians2,alpha=0.8,bins=50,color='r',density=True,range=(-0.1,0.1))
    ax.get_legend()

    ax.set_xlabel("Medijan intenziteta svjetlosti", fontsize=20)
   # ax.set_ylabel('Num. of Stars')
    ax = fig.add_subplot(233)    
    ax.hist(std1,alpha=0.8,bins=50,color='b',range=(0,4000))
    #ax.hist(std2,alpha=0.8,bins=50,color='r',density=True,range=(0,4000))
    ax.get_legend()

    ax.set_xlabel("Standardna devijacija intenziteta svjetlosti", fontsize=20)
    #ax.set_ylabel('Num. of Stars')
    ax = fig.add_subplot(234)
    ax.hist(maxval1,alpha=0.8,bins=50,color='b',range=(-10000,50000))
    #ax.hist(maxval2,alpha=0.8,bins=50,color='r',density=True,range=(-10000,50000))
    ax.get_legend()

    ax.set_xlabel("Najveći intenziteti svjetlosti", fontsize=20)
    ax.set_ylabel("Broj zvijezdi", fontsize=20)
    ax = fig.add_subplot(235)
    ax.hist(minval1,alpha=0.8,bins=50,color='b',range=(-50000,10000))
    #ax.hist(minval2,alpha=0.8,bins=50,color='r',density=True,range=(-50000,10000))
    ax.get_legend()

    ax.set_xlabel("Najmanji intenziteti svjetlosti", fontsize=20)
    #ax.set_ylabel('Num. of Stars')
    ax = fig.add_subplot(236)
    ax.hist(skew1,alpha=0.8,bins=50,color='b',range=(-40,60))
    #ax.hist(skew2,alpha=0.8,bins=50,color='r',density=True,range=(-40,60)) 
    ax.get_legend()

    ax.set_xlabel("Iskrivljenost intenziteta svjetlosti", fontsize=22)
    #ax.set_ylabel('Num. of Stars')

# %%
print("Loading data...")
train_data = pd.read_csv("exoTrain.csv")#.fillna(0)
test_data = pd.read_csv("exoTest.csv")#.fillna(0)
print("Data loaded.")
labels = train_data.LABEL
train_data = train_data.drop('LABEL',axis=1)
# Out:
# Loading data...
# Data loaded.

# %%
plt.rc('xtick', labelsize=18) 
plt.rc('ytick', labelsize=18) 
stats_plots_label(train_data,labels)

# %%
m = np.array([[2],[5]])
m.mean(), m.std()
# Out:
# (3.5, 1.5)

# %%
std = StandardScaler()
std.fit(m)
# Out:
# StandardScaler()

# %%
std.transform(m)
# Out:
# array([[-1.],
#        [ 1.]])

# %%
z = (5-m.mean())/m.std();z
# Out:
# 1.0
